# %% [markdown]
# <a href="https://colab.research.google.com/github/Niranjanc2602/machine_learning_AI_Udemy_learning/blob/dev/Regression/polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Polynomial Regression

# %% [markdown]
# ##import the library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# ##Training the linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ##Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## visualing the linear regression result

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X, lin_reg.predict(X),color ="blue")
plt.title('Truth predit')
plt.xlabel("Position")
plt.ylabel("salary")
plt.show()

# %% [markdown]
# ## Visual the polynomial regression result

# %%
plt.scatter(X,y,color = 'red')
plt.plot(X, lin_reg_2.predict(X_poly),color ="blue")
plt.title('Truth predit')
plt.xlabel("Position")
plt.ylabel("salary")
plt.show()

# %% [markdown]
# ##Predicting a newe result with linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ##Predicting a newe result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([189498.10606061])
